# %%
def say():
  print("말하기")
say()
# Out:
# 말하기

# %%
def say(x):
  print("%s말하기"%x)
say(4)
say("나랑")
# Out:
# 4말하기
# 나랑말하기

# %%
def add(x,y):
  return x+y

print(add(4,5))
print(add("나랑","너랑"))
# Out:
# 9
# 나랑너랑

# %%
class test:
  num = 10
  str = 'hello'
  def show(self):
    print(self.str)
  def pick(self):
    print(self.num)

t = test()
t.show()
t.num = 20
t.pick()
# Out:
# hello
# 20
