# %% [markdown]
# **다중 회귀(시범에 안넣을 예정)**
# * 선형회귀 중에서 다중 회귀(특성 공학)을 다룸
# * 특성 공학: x를 이용해서 x^2을 만드는 식으로 특성을 이용해서 새로운 특성을 만드는 것

# %%
import numpy as np
import pandas as pd #데이터 분석 라이브러리(많이 쓰임)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures #특성을 만드는 변환기
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

df = pd.read_csv('http://bit.ly/perch_csv_data')
perch_full = df.to_numpy()

perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])

#print(perch_full)

train_input, test_input, train_target, test_target = train_test_split(perch_full, perch_weight,random_state=42)

poly = PolynomialFeatures(degree = 2, include_bias=False) #bias가 편향(ax+b의 b를 말해)인데, 이를 생략한다는 뜻
poly.fit(train_input) #AI모델 학습시키는거 아님
train_poly = poly.transform(train_input)
test_poly = poly.transform(test_input)

print(train_poly.shape) #열 3개였는데 이를 특성공학으로 9개로 늘림
print(poly.get_feature_names_out()) #특성 형태를 보는것(a,b,c를 이용해 ab, a^2, ac, b^2등으로 만들어서 늘리는 것)

lr.fit(train_poly,train_target)
print(lr.score(train_poly,train_target))
print(lr.score(test_poly,test_target))
# Out:
# (42, 9)
# ['x0' 'x1' 'x2' 'x0^2' 'x0 x1' 'x0 x2' 'x1^2' 'x1 x2' 'x2^2']
# 0.9903183436982125
# 0.9714559911594111
