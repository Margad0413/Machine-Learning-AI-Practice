# %%
#산점도
import matplotlib.pyplot as plt

#돔 데이터
bream_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0]
bream_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0]

#빙어 데이터
smelt_length = [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
smelt_weight = [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

#print(bream_length)
#print(bream_weight)

plt.scatter(bream_length,bream_weight)
plt.scatter(smelt_length,smelt_weight)
plt.xlabel('length')
plt.ylabel('weight')
#초록색 세모 마커 찍기(x,y,마커종류)
plt.scatter(30,600,marker='*')
plt.show()

# %%
import matplotlib.pyplot as plt
#사이킷 런 패키지
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier(n_neighbors=5)
#주어진 데이터 기준으로 n_neightbors 개수만큼 데이터를 뽑아낸후에 돔 데이터가 몇개인지, 빙어가 몇개인지 판별후 더 많은쪽으로 결론을 낸다.
#가령 n_neightbors = 5 라면 주어진 좌표로부터 가장 가까운 점 5개를 뽑아내고서 이것이 빙어 3개, 돔 2개면 빙어로 판별하고, 확률도 3/5 = 60%쯤으로 나오게 한다는것.
#n_neightbors=49(총 데이터양이 49개)이라면 결국 돔 데이터(30몇개)가 더 많기 때문에 뭘 넣든 돔이라고 판별함.
#n_nrightbors 같은걸 하이퍼 파라미터라고 한다. 줄여서 파라미터. 이 값을 잘 설정하는것이 중요. 성능을 결정하는 수준.

#돔 데이터
bream_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0]
bream_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0]

#빙어 데이터
smelt_length = [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
smelt_weight = [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

length = bream_length + smelt_length
weight = bream_weight + smelt_weight

fish_data = [[l,w] for l,w in zip(length,weight)]
#1은 돔, 0은 빙어
fish_target = [1]*35 + [0]*14

#학습하는 것
kn.fit(fish_data,fish_target)
#정확도 출력(주어진 데이터에 따른)
print(kn.score(fish_data,fish_target))

#주어진 길이, 무게 데이터에 맞게 예측
print(kn.predict([[30,600]]))
print(kn.predict([[10,60]]))

plt.scatter(bream_length,bream_weight)
plt.scatter(smelt_length,smelt_weight)
plt.xlabel('length')
plt.ylabel('weight')
#초록색 세모 마커 찍기(x,y,마커종류)
plt.scatter([30],[600],marker='*',color='blue')
plt.scatter([10],[60],marker='*',color='red')
plt.show()
# Out:
# 1.0
# [1]
# [0]
